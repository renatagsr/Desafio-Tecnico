# %% [markdown]
# # Analise de Dados da quantidade de pessoas negras presentes na universidade
#
# <center><img src="https://image.freepik.com/vetores-gratis/pare-o-conceito-de-racismo-ilustrado-com-pessoas-de-maos-dadas_52683-40170.jpg" width=30%></center>
#
# Não é novidade que o Brasil, culturalmente, não é um país igualitário. É um país onde brancos possuem mais privilégios que os negros, os ricos mais do que os pobres, entre diversas outras diferenças. Diversas medidas têm sido tomadas para mudar essa realidade, uma delas é a instituição de cotas nas universidades, ela estabeleceu que 50% das vagas das faculdades tem que ser destinadas a cotas, sendo divididas para pessoas negras, provenientes de escola pública e de baixa renda, além disso proporciou maior oportunidade para as pessoas negras (pretos e pardos) entrarem na universidade. De 2012 a 2015, por exemplo, segundo o IPEA(Instituto de Pesquisa Econômica Aplicada) o número de vagas reservadas as pessoas negras passou de 140.303 para 247.950, um aumento de cerca de 75% do número de vagas. Isso faz com que se perceba que há maior disponibilidade para os negros entrarem na universidade.
#
# Mesmo com a implantação dessas medidas ainda há muito a que ser feito. Segundo dados de pesquisas publicadas pela Universidade Federal de Juiz de Fora em 2017, apenas 12,8% dos negros (pretos e pardos) com idade entre 18 e 24 anos estão na universidade. Os dados apontam também que apenas cerca de 34% dos estudantes são negros nas universidades. Além da política de cotas outras tem que ser tomadas, como por exemplo, formas de incentivo para os negros continuarem na faculdade, visto que, segundo pesquisas, muitos deles possuem dificuldades para permanecer devido ao necessidade de transporte, moradia, alimentação, entre outros, no período que estão cursando a faculdade.
#
# Nesse notebook será apresentado dados referentes ao aumento da quantidade de pessoas negras presentes na universidade, mostrando que a política de cotas realmente colaborou, porém ainda há o que se fazer. Os dados foram disponibilizados pelo Instituto Nacional de Estudos e Pesquisas Educacionais Anísio Teixeira e podem ser encontrados [aqui](https://www.gov.br/inep/pt-br/areas-de-atuacao/pesquisas-estatisticas-e-indicadores/censo-da-educacao-superior/resultados?_authenticator=73b6b0e03f10cadf5ec8ab8e09e6be4f931e571f).

# %% [markdown]
# Um ponto importante a ser levantado é que antes de fazer a analise em si foi realizada uma limpeza dos dados, que é de grande importância, visto que através da correta limpeza de dados que é possível fazer a analise para obter os resultados desejados.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Analise da quantidade de alunos negros no ensino superior

# %%
columns_ate_2016 = [
    "CO_COR_RACA_ALUNO"
]

# %%
def read_data_until_2016(year_data):
    return pd.read_csv(year_data, sep='|', encoding="latin1", usecols=columns_ate_2016)

# %%
data_2009 = read_data_until_2016('DM_ALUNO_2009_clean.CSV')
data_2010 = read_data_until_2016('DM_ALUNO_2010_clean.CSV')
data_2011 = read_data_until_2016('DM_ALUNO_2011_clean.CSV')
data_2012 = read_data_until_2016('DM_ALUNO_2012_clean.CSV')
data_2013 = read_data_until_2016('DM_ALUNO_2013_clean.CSV')
data_2014 = read_data_until_2016('DM_ALUNO_2014_clean.CSV')
data_2015 = read_data_until_2016('DM_ALUNO_2015_clean.CSV')
data_2016 = read_data_until_2016('DM_ALUNO_2016_clean.CSV')

# %%
columns = [
    "TP_COR_RACA"
]

# %%
def read_data_since_2017(year_data):
    return pd.read_csv(year_data, sep='|', encoding="latin1", usecols=columns)

# %%
data_2017 = read_data_since_2017('DM_ALUNO_2017_clean.CSV')
data_2018 = read_data_since_2017('DM_ALUNO_2018_clean.CSV')
data_2019 = read_data_since_2017('DM_ALUNO_2019_clean.CSV')

# %%
all_black_people_college = []
black_people_college = []
def amount_black_people_until_2016(year_date):
    for data in year_date["CO_COR_RACA_ALUNO"]:
        if data == 2.0 or data == 3:
            black_people_college.append(data)
            all_black_people_college.append(data)
    print(f'Havia \033[1;34m{len(black_people_college)}\033[0;0m na universidade, sendo um total de \033[1;34m{(len(black_people_college)/year_date["CO_COR_RACA_ALUNO"].shape[0]*100):.2f}%\033[0;0m.\n')

def amount_black_people_since_2017(year_date):
    for data in year_date["TP_COR_RACA"]:
        if data == 2 or data == 3:
            black_people_college.append(data)
            all_black_people_college.append(data)
    print(f'Havia \033[1;34m{len(black_people_college)}\033[0;0m na universidade, sendo um total de \033[1;34m{(len(black_people_college)/year_date["TP_COR_RACA"].shape[0]*100):.2f}%\033[0;0m.\n')

# %%
amount_black_people_until_2016(data_2009)
black_people_college_2009 = len(black_people_college)

black_people_college = []
amount_black_people_until_2016(data_2010)
black_people_college_2010 = len(black_people_college)

black_people_college = []
amount_black_people_until_2016(data_2011)
black_people_college_2011 = len(black_people_college)

black_people_college = []
amount_black_people_until_2016(data_2012)
black_people_college_2012 = len(black_people_college)

black_people_college = []
amount_black_people_until_2016(data_2013)
black_people_college_2013 = len(black_people_college)

black_people_college = []
amount_black_people_until_2016(data_2014)
black_people_college_2014 = len(black_people_college)

black_people_college = []
amount_black_people_until_2016(data_2015)
black_people_college_2015 = len(black_people_college)

black_people_college = []
amount_black_people_until_2016(data_2016)
black_people_college_2016 = len(black_people_college)

black_people_college = []
amount_black_people_since_2017(data_2017)
black_people_college_2017 = len(black_people_college)

black_people_college = []
amount_black_people_since_2017(data_2018)
black_people_college_2018 = len(black_people_college)

black_people_college = []
amount_black_people_since_2017(data_2019)
black_people_college_2019 = len(black_people_college)
# Out:
# Havia 580343 na universidade, sendo um total de 8.36%.
#
# Havia 816897 na universidade, sendo um total de 9.87%.
#
# Havia 997256 na universidade, sendo um total de 11.21%.
#
# Havia 1195159 na universidade, sendo um total de 12.58%.
#
# Havia 1432950 na universidade, sendo um total de 14.53%.
#
# Havia 2231803 na universidade, sendo um total de 20.82%.
#
# Havia 2900760 na universidade, sendo um total de 26.07%.
#
# Havia 3308649 na universidade, sendo um total de 29.05%.
#
# Havia 3666048 na universidade, sendo um total de 31.81%.
#
# Havia 4182494 na universidade, sendo um total de 34.92%.
#
# Havia 4594564 na universidade, sendo um total de 37.37%.

# %% [markdown]
# Os resultados comprovam que desde quando iniciou a política de cotas o número de estudantes negros aumentou, dados de pesquisas corroboram essa constatação. Segundo Carla Mereles, jornalista de formação, em 1997 era 1,8% da população negra que ingressou no ensino superior. Em 2011, saltou para 11,9% – ou seja, houve um aumento de quase 1000%. Já segundo pesquisas do IBGE (Instituto Brasileiro de Geografia e Estatística) o quadro mudou de modo importante após uma década em 2015 12,8% de negros entre 18 e 24 anos chegaram no ensino superior.

# %%
print(f'No prazo de 2009 até 2019 houveram \033[1;34m{len(all_black_people_college)}\033[0;0m negros na universidade!')
# Out:
# No prazo de 2009 até 2019 houveram 25906923 negros na universidade!

# %%
percentage_2009 = (black_people_college_2009/data_2009["CO_COR_RACA_ALUNO"].shape[0])*100
percentage_2010 = (black_people_college_2010/data_2010["CO_COR_RACA_ALUNO"].shape[0])*100
percentage_2011 = (black_people_college_2011/data_2011["CO_COR_RACA_ALUNO"].shape[0])*100
percentage_2012 = (black_people_college_2012/data_2011["CO_COR_RACA_ALUNO"].shape[0])*100
percentage_2013 = (black_people_college_2013/data_2011["CO_COR_RACA_ALUNO"].shape[0])*100
percentage_2014 = (black_people_college_2014/data_2011["CO_COR_RACA_ALUNO"].shape[0])*100
percentage_2015 = (black_people_college_2015/data_2011["CO_COR_RACA_ALUNO"].shape[0])*100
percentage_2016 = (black_people_college_2016/data_2011["CO_COR_RACA_ALUNO"].shape[0])*100
percentage_2017 = (black_people_college_2017/data_2017["TP_COR_RACA"].shape[0])*100
percentage_2018 = (black_people_college_2018/data_2017["TP_COR_RACA"].shape[0])*100
percentage_2019 = (black_people_college_2019/data_2017["TP_COR_RACA"].shape[0])*100

# %%
list_all_black_people_college = [percentage_2009, percentage_2010, percentage_2011, percentage_2012,
                                percentage_2013, percentage_2014, percentage_2015, percentage_2016,
                                percentage_2017, percentage_2018, percentage_2019]

date = [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

# %%
def annotate(percentage, year, position):
    return plt.annotate(round(percentage, 2), (year - 0.3, percentage + position))

# %%
fig, ax = plt.subplots(figsize = (10, 6))

ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.plot(date, list_all_black_people_college, marker = 'o')

annotate(percentage_2009, 2009, 2)
annotate(percentage_2010, 2010, 2)
annotate(percentage_2011, 2011, 2)
annotate(percentage_2012, 2012, 2)
annotate(percentage_2013, 2013, 2)
annotate(percentage_2014, 2014, 2)
annotate(percentage_2015, 2015, 2)
annotate(percentage_2016, 2016, 2)
annotate(percentage_2017, 2017, 2)
annotate(percentage_2018, 2018, 2)
annotate(percentage_2019, 2019, 2)

plt.gca().axes.get_yaxis().set_visible(False)
plt.title('Porcentagem de pessoas negras na universidade de 2009 a 2019', fontsize = 16)
plt.xlabel('Anos')
plt.show()

# %% [markdown]
# ## Analise da quantidade de alunos negros em faculdades públicas

# %%
columns_ate_2016 = [
    "CO_CATEGORIA_ADMINISTRATIVA",
    "CO_COR_RACA_ALUNO"
]
columns = [
    "TP_CATEGORIA_ADMINISTRATIVA",
    "TP_COR_RACA"
]

# %%
data_2009 = read_data_until_2016('DM_ALUNO_2009_clean.CSV')
data_2010 = read_data_until_2016('DM_ALUNO_2010_clean.CSV')
data_2011 = read_data_until_2016('DM_ALUNO_2011_clean.CSV')
data_2012 = read_data_until_2016('DM_ALUNO_2012_clean.CSV')
data_2013 = read_data_until_2016('DM_ALUNO_2013_clean.CSV')
data_2014 = read_data_until_2016('DM_ALUNO_2014_clean.CSV')
data_2015 = read_data_until_2016('DM_ALUNO_2015_clean.CSV')
data_2016 = read_data_until_2016('DM_ALUNO_2016_clean.CSV')
data_2017 = read_data_since_2017('DM_ALUNO_2017_clean.CSV')
data_2018 = read_data_since_2017('DM_ALUNO_2018_clean.CSV')
data_2019 = read_data_since_2017('DM_ALUNO_2019_clean.CSV')

# %%
def amount_people_public_college_until_2016(year_data):
    return year_data.loc[(year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 1) | (year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 2) | (year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 3), ["CO_COR_RACA_ALUNO", "CO_CATEGORIA_ADMINISTRATIVA"]]

def amount_people_public_college_since_2017(year_data):
    return year_data.loc[(year_data["TP_CATEGORIA_ADMINISTRATIVA"] == 1) | (year_data["TP_CATEGORIA_ADMINISTRATIVA"] == 2) | (year_data["TP_CATEGORIA_ADMINISTRATIVA"] == 3), ["TP_COR_RACA", "TP_CATEGORIA_ADMINISTRATIVA"]]

# %%
people_public_college_2009 = amount_people_public_college_until_2016(data_2009)
people_public_college_2010 = amount_people_public_college_until_2016(data_2010)
people_public_college_2011 = amount_people_public_college_until_2016(data_2011)
people_public_college_2012 = amount_people_public_college_until_2016(data_2012)
people_public_college_2013 = amount_people_public_college_until_2016(data_2013)
people_public_college_2014 = amount_people_public_college_until_2016(data_2014)
people_public_college_2015 = amount_people_public_college_until_2016(data_2015)
people_public_college_2016 = amount_people_public_college_until_2016(data_2016)
people_public_college_2017 = amount_people_public_college_since_2017(data_2017)
people_public_college_2018 = amount_people_public_college_since_2017(data_2018)
people_public_college_2019 = amount_people_public_college_since_2017(data_2019)

# %%
def amount_black_people_public_college_until_2016(year_data):
    return year_data.loc[((year_data["CO_COR_RACA_ALUNO"] == 2) | (year_data["CO_COR_RACA_ALUNO"] == 3)) & ((year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 1) | (year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 2) | (year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 3)), ["CO_COR_RACA_ALUNO", "CO_CATEGORIA_ADMINISTRATIVA"]]

def amount_black_people_public_college_since_2016(year_data):
    return year_data.loc[((year_data["TP_COR_RACA"] == 2) | (year_data["TP_COR_RACA"] == 3) & ((year_data["TP_CATEGORIA_ADMINISTRATIVA"] == 1) | (year_data["TP_CATEGORIA_ADMINISTRATIVA"] == 2) | (year_data["TP_CATEGORIA_ADMINISTRATIVA"] == 3)), ["TP_COR_RACA", "TP_CATEGORIA_ADMINISTRATIVA"])]

# %%
black_people_public_college_2009 = amount_black_people_public_college_until_2016(data_2009)
print(f'Haviam \033[1;34m{len(black_people_public_college_2009)}\033[0;0m pessoas negras na universidade pública (Federal, Estadual ou Municipal) em 2009, totalizando \033[1;34m{(len(black_people_public_college_2009)/len(people_public_college_2009)*100):.2f}%\033[0;0m.')

black_people_public_college_2010 = amount_black_people_public_college_until_2016(data_2010)
print(f'Haviam \033[1;34m{len(black_people_public_college_2010)}\033[0;0m pessoas negras na universidade pública (Federal, Estadual ou Municipal) em 2010, totalizando \033[1;34m{(len(black_people_public_college_2010)/len(people_public_college_2010)*100):.2f}%\033[0;0m.')

black_people_public_college_2011 = amount_black_people_public_college_until_2016(data_2011)
print(f'Haviam \033[1;34m{len(black_people_public_college_2011)}\033[0;0m pessoas negras na universidade pública (Federal, Estadual ou Municipal) em 2011, totalizando \033[1;34m{(len(black_people_public_college_2011)/len(people_public_college_2011)*100):.2f}%\033[0;0m.')

black_people_public_college_2012 = amount_black_people_public_college_until_2016(data_2012)
print(f'Haviam \033[1;34m{len(black_people_public_college_2012)}\033[0;0m pessoas negras na universidade pública (Federal, Estadual ou Municipal) em 2012, totalizando \033[1;34m{(len(black_people_public_college_2012)/len(people_public_college_2012)*100):.2f}%\033[0;0m.')

black_people_public_college_2013 = amount_black_people_public_college_until_2016(data_2013)
print(f'Haviam \033[1;34m{len(black_people_public_college_2013)}\033[0;0m pessoas negras na universidade pública (Federal, Estadual ou Municipal) em 2013, totalizando \033[1;34m{(len(black_people_public_college_2013)/len(people_public_college_2013)*100):.2f}%\033[0;0m.')

black_people_public_college_2014 = amount_black_people_public_college_until_2016(data_2014)
print(f'Haviam \033[1;34m{len(black_people_public_college_2014)}\033[0;0m pessoas negras na universidade pública (Federal, Estadual ou Municipal) em 2014, totalizando \033[1;34m{(len(black_people_public_college_2014)/len(people_public_college_2014)*100):.2f}%\033[0;0m.')

black_people_public_college_2015 = amount_black_people_public_college_until_2016(data_2015)
print(f'Haviam \033[1;34m{len(black_people_public_college_2015)}\033[0;0m pessoas negras na universidade pública (Federal, Estadual ou Municipal) em 2015, totalizando \033[1;34m{(len(black_people_public_college_2015)/len(people_public_college_2015)*100):.2f}%\033[0;0m.')

black_people_public_college_2016 = amount_black_people_public_college_until_2016(data_2016)
print(f'Haviam \033[1;34m{len(black_people_public_college_2016)}\033[0;0m pessoas negras na universidade pública (Federal, Estadual ou Municipal) em 2016, totalizando \033[1;34m{(len(black_people_public_college_2016)/len(people_public_college_2016)*100):.2f}%\033[0;0m.')

black_people_public_college_2017 = amount_black_people_public_college_since_2016(data_2017)
print(f'Haviam \033[1;34m{len(black_people_public_college_2017)}\033[0;0m pessoas negras na universidade pública (Federal, Estadual ou Municipal) em 2017, totalizando \033[1;34m{(len(black_people_public_college_2017)/len(people_public_college_2017)*100):.2f}%\033[0;0m.')

black_people_public_college_2018 = amount_black_people_public_college_since_2016(data_2018)
print(f'Haviam \033[1;34m{len(black_people_public_college_2018)}\033[0;0m pessoas negras na universidade pública (Federal, Estadual ou Municipal) em 2018, totalizando \033[1;34m{(len(black_people_public_college_2018)/len(people_public_college_2018)*100):.2f}%\033[0;0m.')

black_people_public_college_2019 = amount_black_people_public_college_since_2016(data_2019)
print(f'Haviam \033[1;34m{len(black_people_public_college_2019)}\033[0;0m pessoas negras na universidade pública (Federal, Estadual ou Municipal) em 2019, totalizando \033[1;34m{(len(black_people_public_college_2019)/len(people_public_college_2019)*100):.2f}%\033[0;0m.')
# Out:
# Haviam 212663 pessoas negras na universidade pública (Federal, Estadual ou Municipal) em 2009, totalizando 12.62%.
# Haviam 280775 pessoas negras na universidade pública (Federal, Estadual ou Municipal) em 2010, totalizando 14.29%.
# Haviam 333841 pessoas negras na universidade pública (Federal, Estadual ou Municipal) em 2011, totalizando 15.86%.
# Haviam 383775 pessoas negras na universidade pública (Federal, Estadual ou Municipal) em 2012, totalizando 17.91%.
# Haviam 457238 pessoas negras na universidade pública (Federal, Estadual ou Municipal) em 2013, totalizando 20.89%.
# Haviam 616646 pessoas negras na universidade pública (Federal, Estadual ou Municipal) em 2014, totalizando 27.27%.
# Haviam 724848 pessoas negras na universidade pública (Federal, Estadual ou Municipal) em 2015, totalizando 31.56%.
# Haviam 835832 pessoas negras na universidade pública (Federal, Estadual ou Municipal) em 2016, totalizando 35.67%.
# ...

# %% [markdown]
# Como pode ser visto, ao se comparar a quantidade de alunos negros no ensino superior e a quantidade de alunos no ensino superior público, a proporção é maior para os alunos em ensino superior em faculdade pública. Além disso, percebe-se que também há um aumento na proporção de alunos no ensino superior público desde que se iniciou a política de cotas.

# %%
all_black_people_public_college = len(black_people_public_college_2009) + len(black_people_public_college_2010) + len(black_people_public_college_2011) + len(black_people_public_college_2012) + len(black_people_public_college_2013) + len(black_people_public_college_2014) + len(black_people_public_college_2015) + len(black_people_public_college_2016) + len(black_people_public_college_2017) + len(black_people_public_college_2018) + len(black_people_public_college_2019)


print(f'No prazo de 2009 até 2019 houveram \033[1;34m{all_black_people_public_college}\033[0;0m negros na universidade pública!')
# Out:
# No prazo de 2009 até 2019 houveram 8632405 negros na universidade pública!

# %%
def percentage_data(data, all_people_public_college):
    return(len(data)/len(all_people_public_college))*100

# %%
percentage_2009 = percentage_data(black_people_public_college_2009, people_public_college_2009)
percentage_2010 = percentage_data(black_people_public_college_2010, people_public_college_2010)
percentage_2011 = percentage_data(black_people_public_college_2011, people_public_college_2011)
percentage_2012 = percentage_data(black_people_public_college_2012, people_public_college_2012)
percentage_2013 = percentage_data(black_people_public_college_2013, people_public_college_2013)              
percentage_2014 = percentage_data(black_people_public_college_2014, people_public_college_2014)
percentage_2015 = percentage_data(black_people_public_college_2015, people_public_college_2015)
percentage_2016 = percentage_data(black_people_public_college_2016, people_public_college_2016)
percentage_2017 = percentage_data(black_people_public_college_2017, people_public_college_2017)
percentage_2018 = percentage_data(black_people_public_college_2018, people_public_college_2018)
percentage_2019 = percentage_data(black_people_public_college_2019, people_public_college_2019)

# %%
list_all_black_people_public_college = [percentage_2009, percentage_2010, percentage_2011, percentage_2012,
                                        percentage_2013, percentage_2014, percentage_2015, percentage_2016,
                                        percentage_2017, percentage_2018, percentage_2019]

# %%
fig, ax = plt.subplots(figsize = (10, 6))

ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.plot(date, list_all_black_people_public_college, marker = 'o')

annotate(percentage_2009, 2009, 2)
annotate(percentage_2010, 2010, 2)
annotate(percentage_2011, 2011, 2)
annotate(percentage_2012, 2012, 2)
annotate(percentage_2013, 2013, 2)
annotate(percentage_2014, 2014, 1)
annotate(percentage_2015, 2015, 1)
annotate(percentage_2016, 2016, 3)
annotate(percentage_2017, 2017, 2)
annotate(percentage_2018, 2018, 2)
annotate(percentage_2019, 2019, 2)

plt.gca().axes.get_yaxis().set_visible(False)
plt.title('Porcentagem de pessoas negras na universidade pública de 2009 a 2019', fontsize = 16)
plt.xlabel('Anos')
plt.show()

# %% [markdown]
# ## Analise da quantidade de alunos negros em faculdades públicas, separado por tipo de curso

# %%
columns_ate_2016 = [
    "CO_CATEGORIA_ADMINISTRATIVA",
    "CO_COR_RACA_ALUNO",
    "CO_GRAU_ACADEMICO"
]
columns = [
    "TP_CATEGORIA_ADMINISTRATIVA",
    "TP_COR_RACA",
    "TP_GRAU_ACADEMICO"
]

# %%
data_2009 = read_data_until_2016('DM_ALUNO_2009_clean.CSV')
data_2010 = read_data_until_2016('DM_ALUNO_2010_clean.CSV')
data_2011 = read_data_until_2016('DM_ALUNO_2011_clean.CSV')
data_2012 = read_data_until_2016('DM_ALUNO_2012_clean.CSV')
data_2013 = read_data_until_2016('DM_ALUNO_2013_clean.CSV')
data_2014 = read_data_until_2016('DM_ALUNO_2014_clean.CSV')
data_2015 = read_data_until_2016('DM_ALUNO_2015_clean.CSV')
data_2016 = read_data_until_2016('DM_ALUNO_2016_clean.CSV')
data_2017 = read_data_since_2017('DM_ALUNO_2017_clean.CSV')
data_2018 = read_data_since_2017('DM_ALUNO_2018_clean.CSV')
data_2019 = read_data_since_2017('DM_ALUNO_2019_clean.CSV')

# %% [markdown]
# No período de tempo analisado apenas no ano de 2009 que houve categorização para o tipo de curso "bacharelad e licenciatura, por isso que há uma função separada apenas para esse ano.

# %%
def type_course_2009(year_data):   
    bachelor = year_data.loc[((year_data["CO_COR_RACA_ALUNO"] == 2) | (year_data["CO_COR_RACA_ALUNO"] == 3)) &(year_data["CO_GRAU_ACADEMICO"] == 1) & ((year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 1) | (year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 2) | (year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 3)), ["CO_COR_RACA_ALUNO", "CO_GRAU_ACADEMICO"]]
    print(f"Haviam \033[1;34m{len(bachelor)}\033[0;0m pessoas negras matriculados na universidade pública no curso de bacharelado.")

    degree = year_data.loc[((year_data["CO_COR_RACA_ALUNO"] == 2) | (year_data["CO_COR_RACA_ALUNO"] == 3)) &(year_data["CO_GRAU_ACADEMICO"] == 2)& ((year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 1) | (year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 2) | (year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 3)), ["CO_COR_RACA_ALUNO", "CO_GRAU_ACADEMICO"]]
    print(f"Haviam \033[1;34m{len(degree)}\033[0;0m pessoas negras matriculados na universidade pública no curso de licenciatura.")

    technologist = year_data.loc[((year_data["CO_COR_RACA_ALUNO"] == 2) | (year_data["CO_COR_RACA_ALUNO"] == 3)) &(year_data["CO_GRAU_ACADEMICO"] == 3) & ((year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 1) | (year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 2) | (year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 3)), ["CO_COR_RACA_ALUNO", "CO_GRAU_ACADEMICO"]]
    print(f"Haviam \033[1;34m{len(technologist)}\033[0;0m pessoas negras matriculados na universidade pública no curso de tecnologo.")

    bachelor_degree = year_data.loc[((year_data["CO_COR_RACA_ALUNO"] == 2) | (year_data["CO_COR_RACA_ALUNO"] == 3)) & (year_data["CO_GRAU_ACADEMICO"] == 4) & ((year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 1) | (year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 2) | (year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 3)), ["CO_COR_RACA_ALUNO", "CO_GRAU_ACADEMICO"]]
    print(f"Haviam \033[1;34m{len(bachelor_degree)}\033[0;0m pessoas negras matriculados na universidade pública no curso de bacharelado e licenciatura.")

    black_people_all_types_of_course = len(bachelor) + len(degree) + len(technologist) + len(bachelor_degree)
    print(f'Do total de negros em matriculados em universidade pública \033[1;34m{(len(bachelor)/black_people_all_types_of_course)*100:.2f}%\033[0;0m estão matriculados em bacharelado, \033[1;34m{(len(degree)/black_people_all_types_of_course)*100:.2f}%\033[0;0m estão matriculados em licenciatura, \033[1;34m{(len(technologist)/black_people_all_types_of_course)*100:.2f}%\033[0;0m estão matriculados em tecnologo e \033[1;34m{(len(bachelor_degree)/black_people_all_types_of_course)*100:.2f}%\033[0;0m estão matriculados em bacharelado e licenciatura')

def type_course_until_2016(year_data):
    bachelor = year_data.loc[((year_data["CO_COR_RACA_ALUNO"] == 2) | (year_data["CO_COR_RACA_ALUNO"] == 3)) &(year_data["CO_GRAU_ACADEMICO"] == 1) & ((year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 1) | (year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 2) | (year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 3)), ["CO_COR_RACA_ALUNO", "CO_GRAU_ACADEMICO"]]
    print(f"Haviam \033[1;34m{len(bachelor)}\033[0;0m pessoas negras matriculados no curso de bacharelado.")

    degree = year_data.loc[((year_data["CO_COR_RACA_ALUNO"] == 2) | (year_data["CO_COR_RACA_ALUNO"] == 3)) &(year_data["CO_GRAU_ACADEMICO"] == 2) & ((year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 1) | (year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 2) | (year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 3)), ["CO_COR_RACA_ALUNO", "CO_GRAU_ACADEMICO"]]
    print(f"Haviam \033[1;34m{len(degree)}\033[0;0m pessoas negras matriculados no curso de licenciatura.")

    technologist = year_data.loc[((year_data["CO_COR_RACA_ALUNO"] == 2) | (year_data["CO_COR_RACA_ALUNO"] == 3)) &(year_data["CO_GRAU_ACADEMICO"] == 3) & ((year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 1) | (year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 2) | (year_data["CO_CATEGORIA_ADMINISTRATIVA"] == 3)), ["CO_COR_RACA_ALUNO", "CO_GRAU_ACADEMICO"]]
    print(f"Haviam \033[1;34m{len(technologist)}\033[0;0m pessoas negras matriculados no curso de tecnologo.")

    black_people_all_types_of_course = len(bachelor) + len(degree) + len(technologist) 
    print(f'Do total de negros em matriculados em universidade pública \033[1;34m{(len(bachelor)/black_people_all_types_of_course)*100:.2f}%\033[0;0m estão matriculados em bacharelado, \033[1;34m{(len(degree)/black_people_all_types_of_course)*100:.2f}%\033[0;0m estão matriculados em licenciatura e \033[1;34m{(len(technologist)/black_people_all_types_of_course)*100:.2f}%\033[0;0m estão matriculados em tecnologo.')

def type_course_since_2017(year_data):
    bachelor = year_data.loc[((year_data["TP_COR_RACA"] == 2) | (year_data["TP_COR_RACA"] == 3)) & (year_data["TP_GRAU_ACADEMICO"] == 1) & ((year_data["TP_CATEGORIA_ADMINISTRATIVA"] == 1) | (year_data["TP_CATEGORIA_ADMINISTRATIVA"] == 2) | (year_data["TP_CATEGORIA_ADMINISTRATIVA"] == 3)), ["TP_COR_RACA", "TP_GRAU_ACADEMICO"]]
    print(f"Haviam \033[1;34m{len(bachelor)}\033[0;0m pessoas negras matriculados no curso de bacharelado.")

    degree = year_data.loc[((year_data["TP_COR_RACA"] == 2) | (year_data["TP_COR_RACA"] == 3)) & (year_data["TP_GRAU_ACADEMICO"] == 2) & ((year_data["TP_CATEGORIA_ADMINISTRATIVA"] == 1) | (year_data["TP_CATEGORIA_ADMINISTRATIVA"] == 2) | (year_data["TP_CATEGORIA_ADMINISTRATIVA"] == 3)), ["TP_COR_RACA", "TP_GRAU_ACADEMICO"]]
    print(f"Haviam \033[1;34m{len(degree)}\033[0;0m pessoas negras matriculados no curso de licenciatura.")

    technologist = year_data.loc[((year_data["TP_COR_RACA"] == 2) | (year_data["TP_COR_RACA"] == 3)) & (year_data["TP_GRAU_ACADEMICO"] == 3) & ((year_data["TP_CATEGORIA_ADMINISTRATIVA"] == 1) | (year_data["TP_CATEGORIA_ADMINISTRATIVA"] == 2) | (year_data["TP_CATEGORIA_ADMINISTRATIVA"] == 3)), ["TP_COR_RACA", "TP_GRAU_ACADEMICO"]]
    print(f"Haviam \033[1;34m{len(technologist)}\033[0;0m pessoas negras matriculados no curso de tecnologo.")

    black_people_all_types_of_course = len(bachelor) + len(degree) + len(technologist) 
    print(f'Do total de negros em matriculados em universidade pública \033[1;34m{(len(bachelor)/black_people_all_types_of_course)*100:.2f}%\033[0;0m estão matriculados em bacharelado, \033[1;34m{(len(degree)/black_people_all_types_of_course)*100:.2f}%\033[0;0m estão matriculados em licenciatura e \033[1;34m{(len(technologist)/black_people_all_types_of_course)*100:.2f}%\033[0;0m estão matriculados em tecnologo.')

# %%
print('\nNo ano de 2009...')
type_course_2009(data_2009)
print('\nNo ano de 2010...')
type_course_until_2016(data_2010)
print('\nNo ano de 2011...')
type_course_until_2016(data_2011)
print('\nNo ano de 2012...')
type_course_until_2016(data_2012)
print('\nNo ano de 2013...')
type_course_until_2016(data_2013)
print('\nNo ano de 2014...')
type_course_until_2016(data_2014)
print('\nNo ano de 2015...')
type_course_until_2016(data_2015)
print('\nNo ano de 2016...')
type_course_until_2016(data_2016)
print('\nNo ano de 2017...')
type_course_since_2017(data_2017)
print('\nNo ano de 2018...')
type_course_since_2017(data_2018)
print('\nNo ano de 2019...')
type_course_since_2017(data_2019)
# Out:
# No ano de 2009...
# Haviam 106472 pessoas negras matriculados na universidade pública no curso de bacharelado.
# Haviam 80859 pessoas negras matriculados na universidade pública no curso de licenciatura.
# Haviam 14412 pessoas negras matriculados na universidade pública no curso de tecnologo.
# Haviam 10920 pessoas negras matriculados na universidade pública no curso de bacharelado e licenciatura.
# Do total de negros em matriculados em universidade pública 50.07% estão matriculados em bacharelado, 38.02% estão matriculados em licenciatura, 6.78% estão matriculados em tecnologo e 5.13% estão matriculados em bacharelado e licenciatura
#
# No ano de 2010...
# Haviam 141257 pessoas negras matriculados no curso de bacharelado.
# Haviam 120759 pessoas negras matriculados no curso de licenciatura.
# Haviam 18759 pessoas negras matriculados no curso de tecnologo.
# ...

# %% [markdown]
# Com a analise da proporção de negros em cada tipo de curso, percebe-se que em todos os anos houveram mais alunos negros matriculados em bacharelado, seguido de licenciatura. Tais resultados mostram uma tendência dos alunos irem mais para o curso de bacharelado.

# %% [markdown]
# Após todas as análises realizadas conclui-se que a política de cotas realmente tem favorecido o aumento dos alunos negros nas universidades, tanto pública quando particular. É um ponto extremamente favorável, isso é inegável, porém ainda há muito o que ser feito em relação ao preconceito com os negros no Brasil. Um próximo passo seria o aumento do corpo docente negro e medidas para diminuir a saída dos negros das universidades.
